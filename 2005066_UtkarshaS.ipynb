# %%
room_price=500
a=eval(input("\n enter no. of person in a room: "))
if a<=4:
    room_price=500
    if a>2:
        room_price=eval("500+500*(a-2)")
        print("room price is {}".format(room_price))
    else:
        print("room price is {}".format(room_price))
x=int(input("Enter the no. of person : "))
people=[]
record=[]
for i in range(0,x):
    
    people.append(input('room no:'))
    people.append(input('Name: '))
    people.append(input('sex: '))
    people.append(input('Age: '))
    people.append(input('Contact: '))
    record.append(people)
    people = []
print(record)  
d1={x[0]:x[1:5] for x in record}
print(d1)
newboarder=input("how many nights for stay: ")
print(newboarder)
rooms=20
room_taken=0
rooms_avail=20-room_taken
boarder=0

for boarder in range(1,70):
    if room_taken<20:
        print('room can be alloted')
        a=input("room_no:")
        b=input("name: ")
        c=input("sex: ")
        d=input("Age: ")
        e=input("contact: ")
        d1={'room_no': a,'name': b, 'sex': c, 'Age': d,'contact': e}
        print("new boarder {}".format(d1))
        room_taken+=1
        break
    else:
        print('room cannot be alloted')

print('room avail {}'.format(rooms_avail))
    
print('total revenue generated per room= {}'.format(room_price))
total_income=eval("room_price*(room_taken)")
print('total income:{}'.format(total_income))
if rooms_avail>0:
    rooms_avail-=1
    print('rooms available:{}'.format(rooms_avail))
file=open('New.txt','w')
file.write('room_price')
file.write('d1')
file.write('total_income')
file.write('rooms_avail')
file.close()
# Out:
#  enter no. of person in a room: 1
# room price is 500
# Enter the no. of person : 1
# room no:1
# Name: q
# sex: q
# Age: q
# Contact: q
# [['1', 'q', 'q', 'q', 'q']]
# {'1': ['q', 'q', 'q', 'q']}
# how many nights for stay: 3
# 3
# room can be alloted
# room_no:2
# name: w
# sex: w
# Age: w
# contact: w
# new boarder {'room_no': '2', 'name': 'w', 'sex': 'w', 'Age': 'w', 'contact': 'w'}
# room avail 20
# total revenue generated per room= 500
# total income:500
# rooms available:19
